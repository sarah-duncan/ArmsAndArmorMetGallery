# %% [markdown]
# # Exploration

# %% [markdown]
# This is an analyses of the Met Galleries collection: found at https://metmuseum.github.io/

# %%
import pandas as pd
import json
import requests

# %% [markdown]
# The objects json below returns the toyal number of items and their Ids

# %%
objects = pd.read_json('https://collectionapi.metmuseum.org/public/collection/v1/objects')

# %%
objects
# Out:
#          total  objectIDs
# 0       480374          1
# 1       480374          2
# 2       480374          3
# 3       480374          4
# 4       480374          5
# ...        ...        ...
# 480369  480374     888683
# 480370  480374     888684
# 480371  480374     888686
# 480372  480374     888687
# 480373  480374     888688
#
# [480374 rows x 2 columns]

# %% [markdown]
# It's a large dataset, let's look at one department for this project. The department I will be looking at here is the Arms and Armor department with ID 4.

# %%
arms_objects = pd.read_json('https://collectionapi.metmuseum.org/public/collection/v1/objects?departmentIds=4')

# %%
arms_objects
# Out:
#        total  objectIDs
# 0      13613      21810
# 1      13613      21811
# 2      13613      21812
# 3      13613      21813
# 4      13613      21814
# ...      ...        ...
# 13608  13613     812439
# 13609  13613     816822
# 13610  13613     835052
# 13611  13613     851637
# 13612  13613     851639
#
# [13613 rows x 2 columns]

# %% [markdown]
# The Arms and Armor department has a total of 13614 objects. Let's look at the data we can get for one of these objects

# %%
url = 'https://collectionapi.metmuseum.org/public/collection/v1/objects/22183'
download = requests.get(url=url)

# %%
first_arm =json.loads(download.content)

# %%
first_arm
# Out:
# {'objectID': 22183,
#  'isHighlight': False,
#  'accessionNumber': '14.25.823a, b',
#  'accessionYear': '1914',
#  'isPublicDomain': False,
#  'primaryImage': '',
#  'primaryImageSmall': '',
#  'additionalImages': [],
#  'constituents': None,
#  'department': 'Arms and Armor',
#  'objectName': 'Arm defense and left gauntlet',
#  'title': 'Arm Defense and Left Gauntlet',
#  'culture': 'possibly Italian, Savoy or Spanish',
#  'period': '',
#  'dynasty': '',
#  'reign': '',
#  'portfolio': '',
#  'artistRole': '',
#  'artistPrefix': '',
#  'artistDisplayName': '',
#  'artistDisplayBio': '',
#  'artistSuffix': '',
#  'artistAlphaSort': '',
#  'artistNationality': '',
#  'artistBeginDate': '',
#  'artistEndDate': '',
#  'artistGender': '',
#  'artistWikidata_URL': '',
#  'artistULAN_URL': '',
#  'objectDate': 'ca. 1590',
#  'objectBeginDate': 1565,
#  'objectEndDate': 1615,
#  'medium': 'Steel, gold',
#  'dimensions': 'arm defense (a): H. 19 3/4 in. (50.2 cm); W. 11 3/4 in. (29.8 cm); D. 7 5/8 in. (19.4 cm); Wt. 4 lb. 11.3 oz. (2133 g); left gauntlet (b): H. 9 1/2 in. (24.1 cm); W. 5 1/4 in. (13.3 cm); D. 5 3/8 in. (13.7 cm); Wt. 15.8 oz. (448 g)',
#  'measurements': None,
#  'creditLine': 'Gift of William H. Riggs, 1913',
#  'geographyType': 'Country of Origin',
#  'city': '',
#  'state': '',
#  'county': '',
#  'country': 'Italy',
#  'region': '',
#  'subregion': '',
#  'locale': '',
#  'locus': '',
#  'excavation': '',
#  'river': '',
#  'classification': 'Armor Parts-Arms & Shoulders',
#  'rightsAndReproduction': '',
#  'linkResource': '',
#  'metadataDate': '2021-07-07T04:42:57.957Z',
#  'repository': 'Metropolitan Museum of Art, New York, NY',
#  'objectURL': 'https://www.metmuseum.org/art/collection/search/22183',
#  'tags': None,
#  'objectWikidata_URL': '',
#  'isTimelineWork': False,
#  'GalleryNumber': ''}

# %%
first_arm["objectID"]
# Out:
# 22183

# %%
test_dataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f61a45989f3c> in <module>
# ----> 1 test_dataframe
#
# NameError: name 'test_dataframe' is not defined

# %%
test_dataframe =test_dataframe.append(second_arm, ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ef4acfcaa9e9> in <module>
# ----> 1 test_dataframe =test_dataframe.append(second_arm, ignore_index = True)
#
# NameError: name 'test_dataframe' is not defined

# %%
test_dataframe

# %% [markdown]
# Find the relavent fields.

# %%
second_arm_df = pd.DataFrame([second_arm])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-622425e2db5f> in <module>
# ----> 1 second_arm_df = pd.DataFrame([second_arm])
#
# NameError: name 'second_arm' is not defined

# %%
test_trimmed_dataframe = pd.DataFrame(columns = ['objectID', 
                                                 'isHighlight', 
                                                 'isPublicDomain',
                                                 'objectName', 
                                                 'title', 
                                                 'artistRole',
                                                 'artistDisplayName',
                                                 'artistBeginDate',
                                                 'artistEndDate',
                                                 'objectBeginDate',
                                                 'objectEndDate', 
                                                 'medium',
                                                 'country', 
                                                 'classification'])

# %%
test_trimmed_dataframe

# %%
test_trimmed_dataframe= pd.concat([test_trimmed_dataframe,second_arm_df], join= 'inner', ignore_index="True")

# %%
test_trimmed_dataframe

# %%
first_arm_df = pd.DataFrame([first_arm])

# %%
first_arm_df

# %%
type(first_arm)

# %%
test_trimmed_dataframe= pd.concat([test_trimmed_dataframe,first_arm_df], join= 'inner', ignore_index="True")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-4612aeb6ba74> in <module>
# ----> 1 test_trimmed_dataframe= pd.concat([test_trimmed_dataframe,first_arm_df], join= 'inner', ignore_index="True")
#
# NameError: name 'test_trimmed_dataframe' is not defined

# %%
test_trimmed_dataframe
# Out:
#   objectID isHighlight isPublicDomain                     objectName  \
# 0    22184       False           True                          Armor
# 1    22183       False          False  Arm defense and left gauntlet
#
#                            title artistRole objectBeginDate objectEndDate  \
# 0     Armor of the Dukes of Alba    Armorer            1550          1610
# 1  Arm Defense and Left Gauntlet                       1565          1615
#
#                 medium country                classification
# 0  Steel, gold, silver   Italy       Armor for Man-1/2 Armor
# 1          Steel, gold   Italy  Armor Parts-Arms & Shoulders

# %% [markdown]
# From the data above these are the fields that most interest me.
# Some preliminary questions:
#
#    * What percentage of the collection is highlighted?
#    * What percentage is in the public domain?
#    * How many individual artists are represented?
#    * Who has the most works?
#    * A timeline with the birth and death of the artists.
#    * Which countries are most presented?
#    * Which countries are most highlighted?
#    * Which medium is the most used?
#    * What is classified most often?

# %%
arms_and_armor_df = pd.DataFrame(columns = ['objectID', 
                                                 'isHighlight', 
                                                 'isPublicDomain',
                                                 'objectName', 
                                                 'title', 
                                                 'artistRole',
                                                 'artistDisplayName',
                                                 'artistBeginDate',
                                                 'artistEndDate',
                                                 'objectBeginDate',
                                                 'objectEndDate', 
                                                 'medium',
                                                 'country', 
                                                 'classification'])

# %%
base_url = 'https://collectionapi.metmuseum.org/public/collection/v1/objects/'

# %%
for objectID in arms_objects["objectIDs"]:
    request = requests.get(url=base_url+ str(objectID))
    artifact = json.loads(request.content)
    artifact_df = pd.DataFrame([artifact])
    arms_and_armor_df= pd.concat([arms_and_armor_df,artifact_df], join= 'inner', ignore_index="True")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     308         # Add certificate verification
# --> 309         conn = self._new_conn()
#     310         hostname = self.host
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170         except SocketError as e:
# --> 171             raise NewConnectionError(
#     172                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x00000143B3F4ED00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     445         if new_retry.is_exhausted():
# --> 446             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     447
#
# MaxRetryError: HTTPSConnectionPool(host='collectionapi.metmuseum.org', port=443): Max retries exceeded with url: /public/collection/v1/objects/25038 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000143B3F4ED00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-8-a05c253ebd3d> in <module>
#       1 for objectID in arms_objects["objectIDs"]:
# ----> 2     request = requests.get(url=base_url+ str(objectID))
#       3     artifact = json.loads(request.content)
#       4     artifact_df = pd.DataFrame([artifact])
#       5     arms_and_armor_df= pd.concat([arms_and_armor_df,artifact_df], join= 'inner', ignore_index="True")
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='collectionapi.metmuseum.org', port=443): Max retries exceeded with url: /public/collection/v1/objects/25038 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000143B3F4ED00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
arms_and_armor_df
# Out:
#      objectID isHighlight isPublicDomain  \
# 0       21810       False           True
# 1       21811       False           True
# 2       21812       False          False
# 3       21813       False           True
# 4       21814       False           True
# ...       ...         ...            ...
# 5288    27756       False          False
# 5289    27757       False          False
# 5290    27758       False           True
# 5291    27759       False          False
# 5292    27761       False          False
#
#                                    objectName  \
# 0                                      Gorget
# 1     Blade and mounting for a sword (Katana)
# 2                    Thumb of a left gauntlet
# 3              Fencing shoulder and arm guard
# 4                         Sword guard (Tsuba)
# ...                                       ...
# 5288                       Dagger with sheath
# 5289                  Ritual dagger (Phur pa)
# 5290                  Ritual dagger (Phur pa)
# 5291                  Ritual dagger (Phur pa)
# 5292                  Ritual dagger (Phur pa)
#
#                                                   title artistRole  \
# 0     Gorget of an Officer of the King's American Re...
# 1               Blade and Mounting for a Sword (Katana)
# 2                              Thumb of a Left Gauntlet
# 3                        Fencing Shoulder and Arm Guard
# 4     Sword guard (<i>Tsuba</i>) Depicting Bodhidhar...
# ...                                                 ...        ...
# 5288                                 Dagger with Sheath
# 5289                            Ritual Dagger (Phur Pa)
# 5290                            Ritual Dagger (Phur Pa)
# 5291                            Ritual Dagger (Phur Pa)
# 5292                            Ritual Dagger (Phur Pa)
#
#      artistDisplayName artistBeginDate artistEndDate objectBeginDate  \
# 0                                                               1781
# 1                                                               1801
# 2                                                               1525
# 3                                                               1590
# 4                                                               1701
# ...                ...             ...           ...             ...
# 5288                                                            1701
# 5289                                                            1801
# 5290                                                            1801
# 5291                                                            1801
# 5292                                                            1801
#
#      objectEndDate                                             medium country  \
# 0             1781                                        Brass, gold
# 1             1900  Steel, wood, lacquer, iron, gold, copper-gold ...   Japan
# 2             1575                               Steel, gold, leather  France
# 3             1900                                              Cloth   Japan
# 4             1800                                 Iron, gold, silver   Japan
# ...            ...                                                ...     ...
# 5288          1900                Steel, silver, gold, wood, ray skin   Tibet
# 5289          1900                                               Wood   Tibet
# 5290          1900                                              Brass   Tibet
# 5291          1900                                              Brass   Tibet
# 5292          1900                                              Brass   Tibet
#
#              classification
# 0       Armor Parts-Gorgets
# 1                    Swords
# 2     Armor Parts-Gauntlets
# 3         Fencing Equipment
# 4     Sword Furniture-Tsuba
# ...                     ...
# 5288                Daggers
# 5289                Daggers
# 5290                Daggers
# 5291                Daggers
# 5292                Daggers
#
# [5293 rows x 14 columns]

# %%
i=0

# %%
for objectID in arms_objects["objectIDs"]:
    
    if objectID > 27761:
        if i >= 100:
            print(objectID)
            i=0
        request = requests.get(url=base_url+ str(objectID))
        artifact = json.loads(request.content)
        artifact_df = pd.DataFrame([artifact])
        arms_and_armor_df= pd.concat([arms_and_armor_df,artifact_df], join= 'inner', ignore_index="True")
        i+=1
# Out:
# 29108
# 28096
# 28198
# 28301
# 27858
# 27961
# 28612
# 28712
# 28812
# 28912
# 29014
# 29138
# 29238
# 29340
# 29441
# 29542
# 28324
# 28430
# 28531
# 31423
# 31523
# 31623
# 30333
# 30433
# 30534
# 30634
# 30734
# 29729
# 29935
# 30040
# 30140
# 30240
# 31712
# 32742
# 32859
# 32964
# 33064
# 31938
# 32038
# 32138
# 32241
# 34406
# 30927
# 31027
# 31127
# 31227
# 31327
# 32375
# 32476
# 32576
# 32683
# 35739
# 30779
# 33921
# 34023
# 34127
# 34233
# 33390
# 33490
# 33598
# 33700
# 33800
# 34921
# 35025
# 35134
# 35240
# 35340
# 34451
# 34551
# 34651
# 34751
# 644344
# 788264
# 34321
# 739608
# 634458
# 659408
# 839248
# 33152
# 33252
# 642391

# %%
arms_and_armor_df
# Out:
#       objectID isHighlight isPublicDomain  \
# 0        21810       False           True
# 1        21811       False           True
# 2        21812       False          False
# 3        21813       False           True
# 4        21814       False           True
# ...        ...         ...            ...
# 13433   812439       False           True
# 13434   816822       False           True
# 13435   835052       False           True
# 13436   851637       False           True
# 13437   851639       False           True
#
#                                     objectName  \
# 0                                       Gorget
# 1      Blade and mounting for a sword (Katana)
# 2                     Thumb of a left gauntlet
# 3               Fencing shoulder and arm guard
# 4                          Sword guard (Tsuba)
# ...                                        ...
# 13433                      Flintlock longrifle
# 13434                         Pair of stirrups
# 13435                                    Tools
# 13436                          Armor garniture
# 13437                            Left gauntlet
#
#                                                    title artistRole  \
# 0      Gorget of an Officer of the King's American Re...
# 1                Blade and Mounting for a Sword (Katana)
# 2                               Thumb of a Left Gauntlet
# 3                         Fencing Shoulder and Arm Guard
# 4      Sword guard (<i>Tsuba</i>) Depicting Bodhidhar...
# ...                                                  ...        ...
# 13433                                Flintlock Longrifle   Gunsmith
# 13434                                   Pair of Stirrups
# 13435                                    Armorer's Tools
# 13436  Armor Garniture of George Clifford (1558–1605)...    Armorer
# 13437  Left Gauntlet of Henry (1594–1612), Prince of ...    Armorer
#
#           artistDisplayName artistBeginDate artistEndDate objectBeginDate  \
# 0                                                                    1781
# 1                                                                    1801
# 2                                                                    1525
# 3                                                                    1590
# 4                                                                    1701
# ...                     ...             ...           ...             ...
# 13433  George Schreyer, Sr.            1739          1819            1770
# 13434                                                                1501
# 13435                                                                1601
# 13436          Jacob Halder            1558          1608            1586
# 13437          Jacob Halder            1558          1608            1600
#
#       objectEndDate                                             medium  \
# 0              1781                                        Brass, gold
# 1              1900  Steel, wood, lacquer, iron, gold, copper-gold ...
# 2              1575                               Steel, gold, leather
# 3              1900                                              Cloth
# 4              1800                                 Iron, gold, silver
# ...             ...                                                ...
# 13433          1820           Wood (maple), steel, iron, brass, silver
# 13434          1700                              Copper alloy (bronze)
# 13435          1900                                        Steel, wood
# 13436          1586                      Steel, gold, leather, textile
# 13437          1612                      Steel, gold, leather, textile
#
#              country                 classification
# 0                               Armor Parts-Gorgets
# 1              Japan                         Swords
# 2             France          Armor Parts-Gauntlets
# 3              Japan              Fencing Equipment
# 4              Japan          Sword Furniture-Tsuba
# ...              ...                            ...
# 13433  United States                  Firearms-Guns
# 13434        Myanmar  Equestrian Equipment-Stirrups
# 13435                                 Miscellaneous
# 13436        England                  Armor for Man
# 13437        England          Armor Parts-Gauntlets
#
# [13438 rows x 14 columns]

# %%
import os
with open("preliminary_save.json", "w") as f:
    print(f.write(arms_and_armor_df.to_json()))
# Out:
# 3372052
